# %% [markdown]
# # Interview Trainer Chat Demo
#
# Этот ноутбук только запускает чат-бота.
# Вся бизнес-логика находится в скриптах `src/interview_trainer/*.py`.
#
# Как работать:
# 1. Выполните ячейку импорта и создания бота.
# 2. Выполните ячейку `chatbot.run_interactive()`.
# 3. Общайтесь с ботом в формате чата.
#
# Команды в чате:
# - `next` — следующий вопрос;
# - `summary` — суммаризация текущей сессии;
# - `stop` — завершение интервью.

# %%
from __future__ import annotations

import os
import sys
from pathlib import Path

project_root = Path.cwd()
src_path = project_root / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from interview_trainer.chatbot import InterviewChatbot

chatbot = InterviewChatbot(
    position="Python Backend Developer",
    stack="Python, FastAPI, PostgreSQL",
    level="junior",
    goals="Подготовиться к техническому интервью",
)

# %%
chatbot.run_interactive()
# Out:
# Сессия инициализирована.
# Позиция: Python Backend Developer
# Стек: Python, FastAPI, PostgreSQL
# Уровень: junior
# === ВОПРОС ===
# Объясните разницу между синхронными и асинхронными функциями в FastAPI. В каких сценариях стоит использовать async/await, и как это влияет на производительность приложения с PostgreSQL?
#
# Что желательно раскрыть в ответе:
# - Различия в поведении синхронных и асинхронных функций
# - Применение async/await для I/O-операций (например, запросы к БД)
# - Преимущества асинхронности для масштабируемости
# - Интеграция с асинхронными драйверами PostgreSQL (asyncpg)
#
# Команды: next, summary, stop
#
# Бот:
# === ОЦЕНКА ОТВЕТА ===
# Score: 45/100
#
# Оценка по скиллам:
# - Понимание концепций: 50/100
# - Практическое применение: 40/100
# - Глубина по уровню: 35/100
# - Ясность коммуникации: 55/100
#
# Сильные стороны:
# - Ответ демонстрирует базовые знания по теме.
#
# Слабые стороны:
# - Недостаточно деталей и практических примеров.
#
# Рекомендации:
# ...

# %%
chatbot = InterviewChatbot(
    position="NLP Machine Learning Engineer",
    stack="Python, ML, NLP, LLM",
    level="Lead",
    goals="Подготовиться к техническому интервью",
)

# %%
chatbot.run_interactive()
# Out:
# Сессия инициализирована.
# Позиция: NLP Machine Learning Engineer
# Стек: Python, ML, NLP, LLM
# Уровень: Lead
# === ВОПРОС ===
# Опишите, как вы выбираете архитектуру модели (например, BERT vs GPT vs T5) для конкретной NLP-задачи. Какие ключевые факторы учитываете при этом?
#
# Что желательно раскрыть в ответе:
# - Анализ задачи (классификация, генерация, извлечение сущностей и т.д.)
# - Оценка доступных данных (объем, качество, баланс классов)
# - Требования к скорости инференса и ресурсоемкости
# - Необходимость поддержки многозадачности или контекстуального понимания
# - Возможности тонкой настройки vs. использования как чёрного ящика
#
# Команды: next, summary, stop
#
# Бот:
# === ОЦЕНКА ОТВЕТА ===
# Score: 90/100
#
# Оценка по скиллам:
# - Понимание концепций: 28/100
# - Практическое применение: 27/100
# - Глубина по уровню: 23/100
# - Ясность коммуникации: 12/100
#
# Сильные стороны:
# - Структурированный подход к выбору архитектуры с четким разделением по типам задач
# ...
